# %%
# !nvidia-smi
# Out:
# Sun Feb 15 20:32:31 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   41C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
cd TFT\ training
# Out:
# /TFT training

# %%
# !cd "TFT training"

# %%
ls
# Out:
# master_dataset_clean.csv  test_prepared.csv  train_prepared.csv
# requirements_tft.txt      tft_train.py       val_prepared.csv
# scaler.pkl                thresholds.json

# %%
# !pip install -r requirements_tft.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 5.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.8/399.8 kB 21.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 62.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.2/983.2 kB 82.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.6/853.6 kB 71.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 159.8/159.8 kB 21.6 MB/s eta 0:00:00
# ...

# %%
# !nvidia-smi
# Out:
# Sun Feb 15 20:36:41 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 580.82.07              Driver Version: 580.82.07      CUDA Version: 13.0     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  Tesla T4                       Off |   00000000:00:04.0 Off |                    0 |
# | N/A   38C    P8              9W /   70W |       0MiB /  15360MiB |      0%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# !python tft_train.py
# Out:
# python3: can't open file '/content/tft_train.py': [Errno 2] No such file or directory

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd TFT training
# Out:
# [Errno 2] No such file or directory: 'TFT training'
# /content

# %%
cd drive
# Out:
# /content/drive

# %%
ls
# Out:
# MyDrive/

# %%
cd MyDrive/
# Out:
# /content/drive/MyDrive

# %%
# Out:
# 'Colab Notebooks'/  'Untitled spreadsheet.gsheet'

# %%
cd Colab\ Notebooks
# Out:
# /content/drive/MyDrive/Colab Notebooks

# %%
ls
# Out:
# 'TFT training.ipynb'   Untitled0.ipynb   Untitled1.ipynb

# %%
cd TFT\ training.ipynb
# Out:
# [Errno 20] Not a directory: 'TFT training.ipynb'
# /content/drive/MyDrive/Colab Notebooks

# %%
ls
# Out:
# 'TFT training.ipynb'   Untitled0.ipynb   Untitled1.ipynb

# %%
cd ..
# Out:
# /content/drive/MyDrive

# %%
cd ..
# Out:
# /content/drive

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd TFT\ training
# Out:
# /TFT training

# %%
ls
# Out:
# master_dataset_clean.csv  test_prepared.csv  train_prepared.csv
# requirements_tft.txt      tft_train.py       val_prepared.csv
# scaler.pkl                thresholds.json

# %%
# !python tft_train.py
# Out:
# [FACT CHECK] test has target column 'gold_return_10d': True
# Seed set to 7
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# ...

# %%
# !pip -q install -r requirements_tft.txt

# %%
# !python tft_train.py
# Out:
# [FACT CHECK] test has target column 'gold_return_10d': True
# Seed set to 7
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'loss' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['loss'])`.
# /usr/local/lib/python3.12/dist-packages/lightning/pytorch/utilities/parsing.py:213: Attribute 'logging_metrics' is an instance of `nn.Module` and is already saved during checkpointing. It is recommended to ignore them using `self.save_hyperparameters(ignore=['logging_metrics'])`.
# Using 16bit Automatic Mixed Precision (AMP)
# GPU available: True (cuda), used: True
# TPU available: False, using: 0 TPU cores
# 💡 Tip: For seamless cloud logging and experiment tracking, try installing [litlogger](https://pypi.org/project/litlogger/) to enable LitLogger, which logs metrics and artifacts automatically to the Lightning Experiments platform.
# ...

# %%
# !python tft_train_colab_safe.py
# Out:
# Streaming output truncated to the last 5000 lines.
#                                                               train_loss_epoch:
# Epoch 4/49 ━━━━━━━━━━━━━━━━━━ 0/52 0:00:00 • -:--:-- 0.00it/s v_num: 1.000
#                                                               train_loss_step:
#                                                               1.075 val_loss:
#                                                               1.121
#                                                               train_loss_epoch:
# Epoch 4/49 ━━━━━━━━━━━━━━━━━━ 0/52 0:00:00 • -:--:-- 0.00it/s v_num: 1.000
#                                                               train_loss_step:
#                                                               1.075 val_loss:
#                                                               1.121
#                                                               train_loss_epoch:
# Epoch 4/49 ━━━━━━━━━━━━━━━━━━ 1/52 0:00:00 • -:--:-- 0.00it/s v_num: 1.000
# ...

# %%
# !python tft_train_colab_safe.py
# Out:
# ===== Fold 1 =====
# /TFT training/tft_train_colab_safe.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype("category")
# /TFT training/tft_train_colab_safe.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col] = df[col].astype("category")
# /TFT training/tft_train_colab_safe.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
# !python tft_high_power_rolling_fixed.py
# Out:
# Streaming output truncated to the last 5000 lines.
#                                                               0.592
#                                                               train_loss_epoch:
# Epoch 3/39 ━━━━━━━━━━━━━━━━╺ 56/59 0:00:59 • 0:00:04 0.94it/s v_num: 6.000
#                                                               train_loss_step:
#                                                               0.678 val_loss:
#                                                               0.592
#                                                               train_loss_epoch:
# Epoch 3/39 ━━━━━━━━━━━━━━━━╺ 57/59 0:00:59 • 0:00:03 0.94it/s v_num: 6.000
#                                                               train_loss_step:
#                                                               0.678 val_loss:
#                                                               0.592
#                                                               train_loss_epoch:
# ...
